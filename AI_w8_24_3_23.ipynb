# %% [markdown]
# <a href="https://colab.research.google.com/github/tuananhnguyen512/AI2023_class/blob/main/AI_w8_24_3_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import Perceptron
x=[[0,0],[1,0],[0,1],[1,1]]
y=[0,1,1,1]
model=Perceptron()
model.fit(x,y)
model.score(x,y)
x1=[[0.5,0],[0,0.5],[0.6,0],[0,0.6],[-10,2],[0.1,1],[-0.3,4]]
y1=model.predict(x1)

# %%
x2=[[-0.5,-0.5],[-0.5,0.5],[0.3,-0.5],[-0.1,1]]
y2=[1,1,0,0]
model=Perceptron()
model.fit(x2,y2)
model.score(x2,y2)
# Out:
# 1.0

# %%
from sklearn import datasets
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
iris=datasets.load_iris()
x=iris.data
y=iris.target
print(x[:5])
print(y[:5])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0 0 0 0 0]

# %%
sc=StandardScaler()
sc.fit(x_train)
x_train_std=sc.transform(x_train)
x_test_std=sc.transform(x_test)
print(x_train,x_train_std)
# Out:
# [[5.9 3.  5.1 1.8]
#  [7.2 3.2 6.  1.8]
#  [5.5 3.5 1.3 0.2]
#  [7.3 2.9 6.3 1.8]
#  [4.5 2.3 1.3 0.3]
#  [5.1 3.4 1.5 0.2]
#  [6.3 3.3 6.  2.5]
#  [4.4 3.2 1.3 0.2]
#  [6.3 2.3 4.4 1.3]
#  [4.6 3.2 1.4 0.2]
#  [7.9 3.8 6.4 2. ]
#  [4.4 2.9 1.4 0.2]
#  [5.2 3.4 1.4 0.2]
#  [5.4 3.  4.5 1.5]
#  [6.2 2.2 4.5 1.5]
#  [6.7 3.  5.2 2.3]
#  [7.7 3.  6.1 2.3]
#  [5.7 2.9 4.2 1.3]
#  [5.8 2.7 3.9 1.2]
#  [4.9 2.4 3.3 1. ]
#  [7.2 3.6 6.1 2.5]
#  [5.8 4.  1.2 0.2]
#  [6.3 2.8 5.1 1.5]
#  [6.4 3.2 4.5 1.5]
#  [6.2 2.8 4.8 1.8]
#  [6.  2.2 5.  1.5]
#  [6.3 2.5 5.  1.9]
#  [5.  2.3 3.3 1. ]
#  [5.8 2.8 5.1 2.4]
#  [6.5 3.2 5.1 2. ]
#  [6.9 3.1 5.4 2.1]
#  [5.2 3.5 1.5 0.2]
#  [6.1 2.8 4.  1.3]
#  [6.6 2.9 4.6 1.3]
#  [6.2 3.4 5.4 2.3]
#  [6.3 2.5 4.9 1.5]
#  [7.4 2.8 6.1 1.9]
#  [6.2 2.9 4.3 1.3]
#  [5.7 2.5 5.  2. ]
#  [6.1 2.9 4.7 1.4]
#  [4.8 3.4 1.6 0.2]
#  [5.4 3.4 1.7 0.2]
#  [5.2 4.1 1.5 0.1]
#  [5.1 2.5 3.  1.1]
#  [5.1 3.3 1.7 0.5]
#  [5.  3.5 1.6 0.6]
#  [5.8 2.7 5.1 1.9]
# ...

# %%
#khong scale
model=Perceptron(max_iter=1000,eta0=0.5,random_state=0)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
print(y_test)
print('do chinh xac mo hinh chua scale:',accuracy_score(y_test,y_pred))
# Out:
# [2 0 2 0 2 0 0 0 2 2 2 0 2 0 2 2 0 2 2 2 0 2 0 0 0 2 0 0 0 2 2 2 0 0 2 2 0
#  2 2 0 0 2 2 0 2]
# [2 0 1 0 2 0 0 1 2 2 2 0 1 1 2 2 1 1 2 2 0 2 0 0 0 2 0 1 0 1 1 1 0 0 2 1 0
#  1 1 1 0 2 2 0 1]
# do chinh xac mo hinh chua scale: 0.6666666666666666

# %%
model=Perceptron(max_iter=10000,eta0=0.5,random_state=0)
model.fit(x_train,y_train)
y_pred=model.predict(x_test_std)
print(y_pred)
print(y_test)
print('do chinh xac mo hinh chua scale:',accuracy_score(y_test,y_pred))
# Out:
# [2 1 2 1 2 1 1 1 2 2 2 0 1 1 2 2 1 1 2 2 0 2 1 1 0 2 1 1 0 1 2 1 1 0 2 2 0
#  2 1 0 0 2 2 0 1]
# [2 0 1 0 2 0 0 1 2 2 2 0 1 1 2 2 1 1 2 2 0 2 0 0 0 2 0 1 0 1 1 1 0 0 2 1 0
#  1 1 1 0 2 2 0 1]
# do chinh xac mo hinh chua scale: 0.7111111111111111

# %%
import pandas as pd
# create url
url = '/content/crabs.csv'
# load data
data = pd.read_csv(url)
# show data
data.head()
# Out:
#   speies sex  index  fontallip  rearwidth  length  width  depth
# 0      B   M      1        8.1        6.7    16.1   19.0    7.0
# 1      B   M      2        8.8        7.7    18.1   20.8    7.4
# 2      B   M      3        9.2        7.8    19.0   22.4    7.7
# 3      B   M      4        9.6        7.9    20.1   23.1    8.2
# 4      B   M      5        9.8        8.0    20.3   23.0    8.2

# %%
x=data['speies'].replace('B','0').head()
y=data['sex'].replace('M','1').head()

# %%
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: sex, dtype: object

# %%
data['speies'].replace(['B','0'],inplace=True)
data['sex'].replace(['M','1'],inplace=True)
data
# Out:
#     speies sex  index  fontallip  rearwidth  length  width  depth
# 0        B   M      1        8.1        6.7    16.1   19.0    7.0
# 1        B   M      2        8.8        7.7    18.1   20.8    7.4
# 2        B   M      3        9.2        7.8    19.0   22.4    7.7
# 3        B   M      4        9.6        7.9    20.1   23.1    8.2
# 4        B   M      5        9.8        8.0    20.3   23.0    8.2
# ..     ...  ..    ...        ...        ...     ...    ...    ...
# 195      O   F     46       21.4       18.0    41.2   46.2   18.7
# 196      O   F     47       21.7       17.1    41.7   47.2   19.6
# 197      O   F     48       21.9       17.2    42.6   47.4   19.5
# 198      O   F     49       22.5       17.2    43.0   48.7   19.8
# 199      O   F     50       23.1       20.2    46.2   52.5   21.1
#
# [200 rows x 8 columns]

# %%
# load library
import pandas as pd
# create url
url = '/content/lung_cancer_examples.csv'
# load data
ung = pd.read_csv(url)

ung.drop('Name',axis=1,inplace=True)
ung.drop('Surname',axis=1,inplace=True)
ung.drop('Result',axis=1,inplace=True)
ung
# Out:
#     Age  Smokes  AreaQ  Alkhol
# 0    35       3      5       4
# 1    27      20      2       5
# 2    30       0      5       2
# 3    28       0      8       1
# 4    68       4      5       6
# 5    34       0     10       0
# 6    58      15     10       0
# 7    22      12      5       2
# 8    45       2      6       0
# 9    52      18      4       5
# 10   33       4      8       0
# 11   18      10      6       3
# 12   25       2      5       1
# 13   28      20      2       8
# 14   34      25      4       8
# 15   39      18      8       1
# 16   42      22      3       5
# 17   19      12      8       0
# 18   62       5      4       3
# 19   73      10      7       6
# 20   55      15      1       3
# 21   33       8      8       1
# 22   22      20      6       2
# 23   44       5      8       1
# 24   77       3      2       6
# 25   21      20      5       3
# 26   37      15      6       2
# 27   34      12      8       0
# 28   55      20      1       4
# ...
